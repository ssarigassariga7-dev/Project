# %%
import pandas as pd

df=pd.read_csv("Data.csv")
df.head(8)
# Out:
#   Student_ID        Student_Name Class  Maths  Science  English  Computer  \
# 0    STU0001         Kavya Kumar    8A     51       48       37        33
# 1    STU0002       Diya Krishnan    9A     24       23       31        47
# 2    STU0003     Kiran Vasudevan    6A     91       45       89        73
# 3    STU0004       Devi Krishnan    8A     20       40       74        63
# 4    STU0005         Meera Menon    8B     33       31       68        32
# 5    STU0006   Prakash Vasudevan    8A     25       78       88        35
# 6    STU0007  Ananya Subramaniam    8A    100       99       66        93
# 7    STU0008       Ishaan Sharma    7B     57       30       49        32
#
#    Social  Average Grade Result
# 0      89     51.6     D   Fail
# 1      49     34.8     F   Fail
# 2      48     69.2     C   Pass
# 3      55     50.4     D   Fail
# 4      65     45.8     E   Fail
# 5      68     58.8     D   Fail
# 6      44     80.4     A   Pass
# 7      68     47.2     E   Fail

# %%
df.tail()
# Out:
#     Student_ID     Student_Name Class  Maths  Science  English  Computer  \
# 995    STU0996  Krishna Pandian    7B     66       79       38        50
# 996    STU0997  Keerthana Naidu    9A     60       28       46        72
# 997    STU0998       Nisha Iyer    8A     96       50       71        50
# 998    STU0999      Meera Menon    6A     51       59       79        82
# 999    STU1000    Bhavana Naidu    6A     45       40       54        37
#
#      Social  Average Grade Result
# 995      39     54.4     D   Pass
# 996      54     52.0     D   Fail
# 997      34     60.2     C   Fail
# 998      91     72.4     B   Pass
# 999      23     39.8     E   Fail

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    1000 non-null   object
#  1   Student_Name  1000 non-null   object
#  2   Class         1000 non-null   object
#  3   Maths         1000 non-null   int64
#  4   Science       1000 non-null   int64
#  5   English       1000 non-null   int64
#  6   Computer      1000 non-null   int64
#  7   Social        1000 non-null   int64
#  8   Average       1000 non-null   float64
#  9   Grade         1000 non-null   object
#  10  Result        1000 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 86.1+ KB

# %%
df.describe()
# Out:
#              Maths      Science      English     Computer     Social  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.0000
# mean     61.369000    59.888000    59.727000    60.185000    61.8030
# std      23.903351    23.255199    23.005385    23.373812    22.8443
# min      20.000000    20.000000    20.000000    20.000000    20.0000
# 25%      41.000000    39.000000    39.000000    40.000000    42.0000
# 50%      62.000000    60.500000    59.000000    60.000000    63.0000
# 75%      82.000000    80.000000    80.000000    81.000000    81.0000
# max     100.000000   100.000000   100.000000   100.000000   100.0000
#
#            Average
# count  1000.000000
# mean     60.594400
# std      10.492889
# min      29.400000
# 25%      53.200000
# 50%      60.600000
# 75%      68.250000
# max      91.800000

# %%
df.isnull().sum()
# Out:
# Student_ID      0
# Student_Name    0
# Class           0
# Maths           0
# Science         0
# English         0
# Computer        0
# Social          0
# Average         0
# Grade           0
# Result          0
# dtype: int64

# %%
subjects = ['Maths','Science','English','Computer','Social']
df['Total'] = df[subjects].sum(axis=1)

df[['Student_Name','Total']].head(7)
# Out:
#          Student_Name  Total
# 0         Kavya Kumar    258
# 1       Diya Krishnan    174
# 2     Kiran Vasudevan    346
# 3       Devi Krishnan    252
# 4         Meera Menon    229
# 5   Prakash Vasudevan    294
# 6  Ananya Subramaniam    402

# %%
df['Average']=df[subjects].mean(axis=1)

df[['Student_Name','Average']].head(7)
# Out:
#          Student_Name  Average
# 0         Kavya Kumar     51.6
# 1       Diya Krishnan     34.8
# 2     Kiran Vasudevan     69.2
# 3       Devi Krishnan     50.4
# 4         Meera Menon     45.8
# 5   Prakash Vasudevan     58.8
# 6  Ananya Subramaniam     80.4

# %%
df.columns
# Out:
# Index(['Student_ID', 'Student_Name', 'Class', 'Maths', 'Science', 'English',
#        'Computer', 'Social', 'Average', 'Grade', 'Result', 'Total'],
#       dtype='object')

# %%
def grade(avg):

    if avg >=90:

        return 'A+'

    elif avg >=80:

        return 'A'

    elif avg >=70:

        return 'B'

    elif avg >=60:

        return 'C'

    elif avg >=50:

        return 'D'

    else:

        return 'F'

df['Grade'] = df['Average'].apply(grade)

df[['Student_Name','Average','Grade']].tail(7)
# Out:
#            Student_Name  Average Grade
# 993  Esther Subramaniam     68.8     C
# 994         Jagan Menon     81.4     A
# 995     Krishna Pandian     54.4     D
# 996     Keerthana Naidu     52.0     D
# 997          Nisha Iyer     60.2     C
# 998         Meera Menon     72.4     B
# 999       Bhavana Naidu     39.8     F

# %%
df[subjects].mean()
# Out:
# Maths       61.369
# Science     59.888
# English     59.727
# Computer    60.185
# Social      61.803
# dtype: float64

# %%
df[subjects].min()
# Out:
# Maths       20
# Science     20
# English     20
# Computer    20
# Social      20
# dtype: int64

# %%
df[subjects].max()
# Out:
# Maths       100
# Science     100
# English     100
# Computer    100
# Social      100
# dtype: int64

# %%
df[df['Maths']>90]
# Out:
#     Student_ID        Student_Name Class  Maths  Science  English  Computer  \
# 2      STU0003     Kiran Vasudevan    6A     91       45       89        73
# 6      STU0007  Ananya Subramaniam    8A    100       99       66        93
# 13     STU0014     Anjali Krishnan    9A     94       71       66        48
# 22     STU0023          Suresh Raj   10A     97       74       47        89
# 25     STU0026       Sandeep Kumar    6B    100       27       49        28
# ..         ...                 ...   ...    ...      ...      ...       ...
# 940    STU0941      Deepika Murthy    6B     96       66       94        81
# 946    STU0947        Murali Reddy   10A     94       65       38        21
# 981    STU0982    Prakash Krishnan    6A    100       63       68        32
# 986    STU0987             Uma Rao    8B     93       32       82        32
# 997    STU0998          Nisha Iyer    8A     96       50       71        50
#
#      Social  Average Grade Result  Total
# ...

# %%
import matplotlib.pyplot as plt
subject_avg = df[subjects].mean()


subject_avg.plot(kind='bar',color=['green','blue','red','orange','pink'])


plt.title('Average Marks by Subject')
plt.xlabel('Subjects')
plt.ylabel('Average Marks')
plt.show()

# %%
import matplotlib.pyplot as plt

df['Status'] = df['Grade'].apply(lambda x: 'Pass'if x != 'F'else'Fail')

df['Status'].value_counts().plot(
 kind='pie',
 autopct='%1.1f%%'
)

plt.title('Pass vs Fail')
plt.ylabel('')

plt.show()
